# %%
import sys
# !{sys.executable} -m pip install mysql-connector-python

import mysql.connector
import pandas as pd

# 1. Create the connection to your local database
try:
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='9752543875', # Replace with your password
        database='retail_db'
    )
    print("Database connection successful! 🎉")

    # 2. Write the exact SQL query you tested in Workbench
    query = """
    SELECT
        Category,
        ROUND(SUM(Sales), 2) AS Total_Revenue,
        ROUND(SUM(Profit), 2) AS Total_Profit
    FROM `global superstore raw`
    GROUP BY Category
    ORDER BY Total_Profit DESC;
    """

    # 3. Pull the data directly into a Pandas DataFrame
    df = pd.read_sql(query, connection)

    # 4. Display the results
    print("\nHere is your Pandas DataFrame:")
    print(df)

except mysql.connector.Error as err:
    print(f"Error: '{err}'")

finally:
    # Always close the connection when you are done
    if 'connection' in locals() and connection.is_connected():
        connection.close()
        print("\nDatabase connection closed.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 48.4 MB/s eta 0:00:00
# ...
# Error: '2003: Can't connect to MySQL server on 'localhost:3306' (Errno 111: Connection refused)'

# %% [markdown]
# # Task
# Load the `csv file.csv` into a Pandas DataFrame and display its head.

# %% [markdown]
# ## Load CSV into Pandas DataFrame
#
# ### Subtask:
# Load the `csv file.csv` into a Pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# First, import the pandas library if it isn't already imported, and then load the `csv file.csv` into a Pandas DataFrame named `df` as per the instructions. Displaying the head will confirm successful loading.

# %%
import pandas as pd

df = pd.read_csv('/content/csv file.csv')
print("DataFrame loaded successfully. Here are the first 5 rows:")
print(df.head())
# Out:
# DataFrame loaded successfully. Here are the first 5 rows:
#           Category  Total_Revenue  Total_Profit
# 0       Technology      288803.06      47824.77
# 1  Office Supplies      157965.95      44664.57
# 2        Furniture      187232.04      22398.52

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the data has been successfully loaded into a Pandas DataFrame and is ready for further analysis within Google Colab.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `csv file.csv` was successfully loaded into a Pandas DataFrame named `df`.
# *   The head of the DataFrame was displayed, confirming it contains three columns: `Category`, `Total_Revenue`, and `Total_Profit`.
# *   The first three rows of the DataFrame show sample data, such as 'Technology' with a `Total_Revenue` of 288803.06 and a `Total_Profit` of 47824.77.
#
# ### Insights or Next Steps
# *   The data is now successfully loaded and formatted as a Pandas DataFrame, making it ready for subsequent analytical tasks.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")

ax = sns.barplot(
    x='Category',
    y='Total_Profit',
    data=df,
    palette='viridis'
)

plt.title('Total Profit by Category', fontsize=16, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Total Profit ($)', fontsize=12)

# ---> Add this line right here! <---
plt.savefig('profit_chart.png', dpi=300, bbox_inches='tight')

# This must always be the very last line
plt.show()
# Out:
# /tmp/ipython-input-401/2695008760.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
